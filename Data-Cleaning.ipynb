# %%
import pandas as pd
import numpy as np

# %%
nfl_data = pd.read_csv("NFL Play by Play 2009-2017 (v4).csv")
np.random.seed(0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (25,51) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
nfl_data.head()
# Out:
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# 2          37.0         PIT  ...       NaN     0.551088     0.448912
# 3          41.0         PIT  ... -5.031425     0.510793     0.489207
# 4           8.0         PIT  ...       NaN     0.461217     0.538783
#
#    Home_WP_post  Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# ...

# %%
nfl_missing_value = nfl_data.isnull().sum()
nfl_missing_value
# Out:
# Date             0
# GameID           0
# Drive            0
# qtr              0
# down         61154
#              ...
# Win_Prob     25009
# WPA           5541
# airWPA      248501
# yacWPA      248762
# Season           0
# Length: 102, dtype: int64

# %%
total_cell = np.product(nfl_data.shape)
total_missing = nfl_missing_value.sum()

(total_missing/total_cell) * 100
# Out:
# 24.87214126835169

# %%
nfl_missing_value[0:10]
# Out:
# Date                0
# GameID              0
# Drive               0
# qtr                 0
# down            61154
# time              224
# TimeUnder           0
# TimeSecs          224
# PlayTimeDiff      444
# SideofField       528
# dtype: int64

# %% [markdown]
# # Drop NFL missing data

# %%
nfl_data.dropna()
# Out:
# Empty DataFrame
# ...

# %%
columns_with_na_dropped = nfl_data.dropna(axis=1)
columns_with_na_dropped.head()
# Out:
#          Date      GameID  Drive  qtr  TimeUnder  ydstogo  ydsnet  \
# 0  2009-09-10  2009091000      1    1         15        0       0
# 1  2009-09-10  2009091000      1    1         15       10       5
# 2  2009-09-10  2009091000      1    1         15        5       2
# 3  2009-09-10  2009091000      1    1         14        8       2
# 4  2009-09-10  2009091000      1    1         14        8       2
#
#    PlayAttempted  Yards.Gained  sp  ...  Timeout_Indicator  Timeout_Team  \
# 0              1            39   0  ...                  0          None
# 1              1             5   0  ...                  0          None
# 2              1            -3   0  ...                  0          None
# 3              1             0   0  ...                  0          None
# 4              1             0   0  ...                  0          None
#
#    posteam_timeouts_pre HomeTimeouts_Remaining_Pre AwayTimeouts_Remaining_Pre  \
# ...

# %%
print(f"column in original dataset: {nfl_data.shape[1]} \n")
print(f"column in dropped dataset: {columns_with_na_dropped.shape[1]} \n")
# Out:
# column in original dataset: 102
#
# column in dropped dataset: 41

# %% [markdown]
# # Fill The Missing Value

# %%
subset_nfl_data = nfl_data.loc[:, 'EPA' : 'Season']
subset_nfl_data
# Out:
#              EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0       2.014474       NaN       NaN     0.485675     0.514325      0.546433
# 1       0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2      -1.402760       NaN       NaN     0.551088     0.448912      0.510793
# 3      -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4       2.097796       NaN       NaN     0.461217     0.538783      0.558929
# ...          ...       ...       ...          ...          ...           ...
# 407683  0.000000       NaN       NaN          NaN          NaN           NaN
# 407684 -0.340818  0.056697 -0.397515     0.080409     0.919591      0.050478
# 407685  0.139913 -2.317201  2.457114     0.050478     0.949522      0.030881
# 407686  0.000000       NaN       NaN     0.030881     0.969119      0.000000
# 407687  0.000000       NaN       NaN     0.000000     1.000000      0.000000
#
# ...

# %%
subset_nfl_data.fillna(0)
# Out:
#              EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0       2.014474  0.000000  0.000000     0.485675     0.514325      0.546433
# 1       0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2      -1.402760  0.000000  0.000000     0.551088     0.448912      0.510793
# 3      -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4       2.097796  0.000000  0.000000     0.461217     0.538783      0.558929
# ...          ...       ...       ...          ...          ...           ...
# 407683  0.000000  0.000000  0.000000     0.000000     0.000000      0.000000
# 407684 -0.340818  0.056697 -0.397515     0.080409     0.919591      0.050478
# 407685  0.139913 -2.317201  2.457114     0.050478     0.949522      0.030881
# 407686  0.000000  0.000000  0.000000     0.030881     0.969119      0.000000
# 407687  0.000000  0.000000  0.000000     0.000000     1.000000      0.000000
#
# ...

# %%
subset_nfl_data.fillna(method = 'bfill', axis = 0).fillna(0)
# Out:
#              EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0       2.014474 -1.068169  1.146076     0.485675     0.514325      0.546433
# 1       0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2      -1.402760  3.318841 -5.031425     0.551088     0.448912      0.510793
# 3      -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4       2.097796 -0.343085  0.163935     0.461217     0.538783      0.558929
# ...          ...       ...       ...          ...          ...           ...
# 407683  0.000000  0.056697 -0.397515     0.080409     0.919591      0.050478
# 407684 -0.340818  0.056697 -0.397515     0.080409     0.919591      0.050478
# 407685  0.139913 -2.317201  2.457114     0.050478     0.949522      0.030881
# 407686  0.000000  0.000000  0.000000     0.030881     0.969119      0.000000
# 407687  0.000000  0.000000  0.000000     0.000000     1.000000      0.000000
#
# ...

# %% [markdown]
# # Now Clean SFB_Data

# %%
sfb_data = pd.read_csv("Building_Permits.csv")
np.random.seed(0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (22,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
sfb_data.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# ...

# %%
sfb_misssing_value = sfb_data.isnull().sum()
sfb_misssing_value[0:10]
# Out:
# Permit Number                  0
# Permit Type                    0
# Permit Type Definition         0
# Permit Creation Date           0
# Block                          0
# Lot                            0
# Street Number                  0
# Street Number Suffix      196684
# Street Name                    0
# Street Suffix               2768
# dtype: int64

# %%
total_cell2 = np.product(sfb_data.shape)
total_missing2 = sfb_misssing_value.sum()

(total_missing2/total_cell2) *100
# Out:
# 26.26002315058403

# %%
sfb_misssing_value[0:10]
# Out:
# Permit Number                  0
# Permit Type                    0
# Permit Type Definition         0
# Permit Creation Date           0
# Block                          0
# Lot                            0
# Street Number                  0
# Street Number Suffix      196684
# Street Name                    0
# Street Suffix               2768
# dtype: int64

# %% [markdown]
# # Now Drop The missing value

# %%
sfb_data.dropna()
# Out:
# Empty DataFrame
# Columns: [Permit Number, Permit Type, Permit Type Definition, Permit Creation Date, Block, Lot, Street Number, Street Number Suffix, Street Name, Street Suffix, Unit, Unit Suffix, Description, Current Status, Current Status Date, Filed Date, Issued Date, Completed Date, First Construction Document Date, Structural Notification, Number of Existing Stories, Number of Proposed Stories, Voluntary Soft-Story Retrofit, Fire Only Permit, Permit Expiration Date, Estimated Cost, Revised Cost, Existing Use, Existing Units, Proposed Use, Proposed Units, Plansets, TIDF Compliance, Existing Construction Type, Existing Construction Type Description, Proposed Construction Type, Proposed Construction Type Description, Site Permit, Supervisor District, Neighborhoods - Analysis Boundaries, Zipcode, Location, Record ID]
# Index: []
#
# [0 rows x 43 columns]

# %%
columns_with_na_dropped2 = sfb_data.dropna(axis = 1)
columns_with_na_dropped2.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Name Current Status  \
# 0           05/06/2015  0326  023            140       Ellis        expired
# 1           04/19/2016  0306  007            440       Geary         issued
# 2           05/27/2016  0595  203           1647     Pacific      withdrawn
# 3           11/07/2016  0156  011           1230     Pacific       complete
# 4           11/28/2016  0342  001            950      Market         issued
#
#   Current Status Date  Filed Date      Record ID
# 0          12/21/2017  05/06/2015  1380611233945
# ...

# %%
print(f"Columns in Original Dataset: {sfb_data.shape[1]}\n")
print(f"Columns in dropped dataset: {columns_with_na_dropped2.shape[1]}")
# Out:
# Columns in Original Dataset: 43
#
# Columns in dropped dataset: 12

# %% [markdown]
# # Now Filling The missing Value

# %%
subset_sfb_data = sfb_data.loc[:,'Permit Number':'Record ID']
subset_sfb_data
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# ...

# %%
subset_sfb_data.fillna(0)
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# ...

# %%
subset_sfb_data.fillna(method = 'bfill', axis = 0).fillna(0)
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# ...
